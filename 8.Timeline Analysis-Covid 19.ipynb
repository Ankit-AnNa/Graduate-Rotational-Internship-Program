# %% [markdown]
# # Covid_19 Analysis :

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_excel('owid-covid-data.xlsx')
df
# Out:
#       iso_code continent       location        date  total_cases  new_cases  \
# 0          AFG      Asia    Afghanistan  2019-12-31          NaN        0.0
# 1          AFG      Asia    Afghanistan  2020-01-01          NaN        0.0
# 2          AFG      Asia    Afghanistan  2020-01-02          NaN        0.0
# 3          AFG      Asia    Afghanistan  2020-01-03          NaN        0.0
# 4          AFG      Asia    Afghanistan  2020-01-04          NaN        0.0
# ...        ...       ...            ...         ...          ...        ...
# 55242      NaN       NaN  International  2020-11-03        696.0        NaN
# 55243      NaN       NaN  International  2020-11-04        696.0        NaN
# 55244      NaN       NaN  International  2020-11-05        696.0        NaN
# 55245      NaN       NaN  International  2020-11-06        696.0        NaN
# 55246      NaN       NaN  International  2020-11-07        696.0        NaN
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                     NaN           NaN         0.0                  NaN  ...
# 1                     NaN           NaN         0.0                  NaN  ...
# 2                     NaN           NaN         0.0                  NaN  ...
# 3                     NaN           NaN         0.0                  NaN  ...
# 4                     NaN           NaN         0.0                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 55242                 NaN           7.0         NaN                  NaN  ...
# 55243                 NaN           7.0         NaN                  NaN  ...
# 55244                 NaN           7.0         NaN                  NaN  ...
# 55245                 NaN           7.0         NaN                  NaN  ...
# 55246                 NaN           7.0         NaN                  NaN  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0            1803.987              NaN                597.029
# 1            1803.987              NaN                597.029
# 2            1803.987              NaN                597.029
# 3            1803.987              NaN                597.029
# 4            1803.987              NaN                597.029
# ...               ...              ...                    ...
# 55242             NaN              NaN                    NaN
# 55243             NaN              NaN                    NaN
# 55244             NaN              NaN                    NaN
# 55245             NaN              NaN                    NaN
# 55246             NaN              NaN                    NaN
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 0                     9.59             NaN           NaN
# 1                     9.59             NaN           NaN
# 2                     9.59             NaN           NaN
# 3                     9.59             NaN           NaN
# 4                     9.59             NaN           NaN
# ...                    ...             ...           ...
# 55242                  NaN             NaN           NaN
# 55243                  NaN             NaN           NaN
# 55244                  NaN             NaN           NaN
# 55245                  NaN             NaN           NaN
# 55246                  NaN             NaN           NaN
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                      37.746                         0.5            64.83
# 1                      37.746                         0.5            64.83
# 2                      37.746                         0.5            64.83
# 3                      37.746                         0.5            64.83
# 4                      37.746                         0.5            64.83
# ...                       ...                         ...              ...
# 55242                     NaN                         NaN              NaN
# 55243                     NaN                         NaN              NaN
# 55244                     NaN                         NaN              NaN
# 55245                     NaN                         NaN              NaN
# 55246                     NaN                         NaN              NaN
#
#        human_development_index
# 0                        0.498
# 1                        0.498
# 2                        0.498
# 3                        0.498
# 4                        0.498
# ...                        ...
# 55242                      NaN
# 55243                      NaN
# 55244                      NaN
# 55245                      NaN
# 55246                      NaN
#
# [55247 rows x 49 columns]

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'tests_per_case', 'positive_rate', 'tests_units', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55247 entries, 0 to 55246
# Data columns (total 49 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   iso_code                            54934 non-null  object
#  1   continent                           54621 non-null  object
#  2   location                            55247 non-null  object
#  3   date                                55247 non-null  object
#  4   total_cases                         51615 non-null  float64
#  5   new_cases                           54324 non-null  float64
#  6   new_cases_smoothed                  53524 non-null  float64
#  7   total_deaths                        42439 non-null  float64
#  8   new_deaths                          54324 non-null  float64
#  9   new_deaths_smoothed                 53524 non-null  float64
#  10  total_cases_per_million             51338 non-null  float64
#  11  new_cases_per_million               54260 non-null  float64
#  12  new_cases_smoothed_per_million      53459 non-null  float64
#  13  total_deaths_per_million            42177 non-null  float64
#  14  new_deaths_per_million              54260 non-null  float64
#  15  new_deaths_smoothed_per_million     53459 non-null  float64
#  16  icu_patients                        3872 non-null   float64
#  17  icu_patients_per_million            3872 non-null   float64
#  18  hosp_patients                       4563 non-null   float64
#  19  hosp_patients_per_million           4563 non-null   float64
#  20  weekly_icu_admissions               328 non-null    float64
#  21  weekly_icu_admissions_per_million   328 non-null    float64
#  22  weekly_hosp_admissions              567 non-null    float64
#  23  weekly_hosp_admissions_per_million  567 non-null    float64
#  24  total_tests                         21044 non-null  float64
#  25  new_tests                           20781 non-null  float64
#  26  total_tests_per_thousand            21044 non-null  float64
#  27  new_tests_per_thousand              20781 non-null  float64
#  28  new_tests_smoothed                  23494 non-null  float64
#  29  new_tests_smoothed_per_thousand     23494 non-null  float64
#  30  tests_per_case                      21752 non-null  float64
#  31  positive_rate                       22118 non-null  float64
#  32  tests_units                         24424 non-null  object
#  33  stringency_index                    45508 non-null  float64
#  34  population                          54934 non-null  float64
#  35  population_density                  52354 non-null  float64
#  36  median_age                          49157 non-null  float64
#  37  aged_65_older                       48418 non-null  float64
#  38  aged_70_older                       48901 non-null  float64
#  39  gdp_per_capita                      48510 non-null  float64
#  40  extreme_poverty                     32337 non-null  float64
#  41  cardiovasc_death_rate               49133 non-null  float64
#  42  diabetes_prevalence                 50924 non-null  float64
#  43  female_smokers                      38259 non-null  float64
#  44  male_smokers                        37766 non-null  float64
#  45  handwashing_facilities              23229 non-null  float64
#  46  hospital_beds_per_thousand          44273 non-null  float64
#  47  life_expectancy                     54229 non-null  float64
#  48  human_development_index             47430 non-null  float64
# dtypes: float64(44), object(5)
# memory usage: 20.7+ MB

# %% [markdown]
# # Selecting location as India-

# %%
ind = df[df['location']=='India']
ind
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 23108      IND      Asia    India  2019-12-31          NaN        0.0
# 23109      IND      Asia    India  2020-01-01          NaN        0.0
# 23110      IND      Asia    India  2020-01-02          NaN        0.0
# 23111      IND      Asia    India  2020-01-03          NaN        0.0
# 23112      IND      Asia    India  2020-01-04          NaN        0.0
# ...        ...       ...      ...         ...          ...        ...
# 23416      IND      Asia    India  2020-11-03    8267623.0    38310.0
# 23417      IND      Asia    India  2020-11-04    8313876.0    46253.0
# 23418      IND      Asia    India  2020-11-05    8364086.0    50210.0
# 23419      IND      Asia    India  2020-11-06    8411724.0    47638.0
# 23420      IND      Asia    India  2020-11-07    8462080.0    50356.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 23108                 NaN           NaN         0.0                  NaN  ...
# 23109                 NaN           NaN         0.0                  NaN  ...
# 23110                 NaN           NaN         0.0                  NaN  ...
# 23111                 NaN           NaN         0.0                  NaN  ...
# 23112                 NaN           NaN         0.0                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 23416           45884.857      123097.0       490.0              513.571  ...
# 23417           46222.000      123611.0       514.0              514.429  ...
# 23418           46269.000      124315.0       704.0              541.143  ...
# 23419           46124.714      124985.0       670.0              556.429  ...
# 23420           46423.000      125562.0       577.0              560.143  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 23108        6426.674             21.2                 282.28
# 23109        6426.674             21.2                 282.28
# 23110        6426.674             21.2                 282.28
# 23111        6426.674             21.2                 282.28
# 23112        6426.674             21.2                 282.28
# ...               ...              ...                    ...
# 23416        6426.674             21.2                 282.28
# 23417        6426.674             21.2                 282.28
# 23418        6426.674             21.2                 282.28
# 23419        6426.674             21.2                 282.28
# 23420        6426.674             21.2                 282.28
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 23108                10.39             1.9          20.6
# 23109                10.39             1.9          20.6
# 23110                10.39             1.9          20.6
# 23111                10.39             1.9          20.6
# 23112                10.39             1.9          20.6
# ...                    ...             ...           ...
# 23416                10.39             1.9          20.6
# 23417                10.39             1.9          20.6
# 23418                10.39             1.9          20.6
# 23419                10.39             1.9          20.6
# 23420                10.39             1.9          20.6
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 23108                   59.55                        0.53            69.66
# 23109                   59.55                        0.53            69.66
# 23110                   59.55                        0.53            69.66
# 23111                   59.55                        0.53            69.66
# 23112                   59.55                        0.53            69.66
# ...                       ...                         ...              ...
# 23416                   59.55                        0.53            69.66
# 23417                   59.55                        0.53            69.66
# 23418                   59.55                        0.53            69.66
# 23419                   59.55                        0.53            69.66
# 23420                   59.55                        0.53            69.66
#
#        human_development_index
# 23108                     0.64
# 23109                     0.64
# 23110                     0.64
# 23111                     0.64
# 23112                     0.64
# ...                        ...
# 23416                     0.64
# 23417                     0.64
# 23418                     0.64
# 23419                     0.64
# 23420                     0.64
#
# [313 rows x 49 columns]

# %%
pd.DataFrame(ind.isnull().sum(), columns= ['Number of missing values'])
# Out:
#                                     Number of missing values
# iso_code                                                   0
# continent                                                  0
# location                                                   0
# date                                                       0
# total_cases                                               31
# new_cases                                                  1
# new_cases_smoothed                                         6
# total_deaths                                              73
# new_deaths                                                 1
# new_deaths_smoothed                                        6
# total_cases_per_million                                   31
# new_cases_per_million                                      1
# new_cases_smoothed_per_million                             6
# total_deaths_per_million                                  73
# new_deaths_per_million                                     1
# new_deaths_smoothed_per_million                            6
# icu_patients                                             313
# icu_patients_per_million                                 313
# hosp_patients                                            313
# hosp_patients_per_million                                313
# weekly_icu_admissions                                    313
# weekly_icu_admissions_per_million                        313
# weekly_hosp_admissions                                   313
# weekly_hosp_admissions_per_million                       313
# total_tests                                               87
# new_tests                                                 93
# total_tests_per_thousand                                  87
# new_tests_per_thousand                                    93
# new_tests_smoothed                                        82
# new_tests_smoothed_per_thousand                           82
# tests_per_case                                            82
# positive_rate                                             82
# tests_units                                               75
# stringency_index                                           9
# population                                                 0
# population_density                                         0
# median_age                                                 0
# aged_65_older                                              0
# aged_70_older                                              0
# gdp_per_capita                                             0
# extreme_poverty                                            0
# cardiovasc_death_rate                                      0
# diabetes_prevalence                                        0
# female_smokers                                             0
# male_smokers                                               0
# handwashing_facilities                                     0
# hospital_beds_per_thousand                                 0
# life_expectancy                                            0
# human_development_index                                    0

# %%
ind['date'] = pd.to_datetime(ind['date'])
# Out:
# <ipython-input-8-47803db5fb3d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ind['date'] = pd.to_datetime(ind['date'])

# %%
ind = ind.drop(['icu_patients','icu_patients_per_million', 'hosp_patients','hosp_patients_per_million', 'weekly_icu_admissions',
       'weekly_icu_admissions_per_million', 'weekly_hosp_admissions','weekly_hosp_admissions_per_million','tests_units','population','population_density','median_age','aged_65_older','aged_70_older','gdp_per_capita', 'extreme_poverty',
       'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
       'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand','life_expectancy', 'human_development_index'], axis=1)

# %%
ind.corr()
# Out:
#                                  total_cases  new_cases  new_cases_smoothed  \
# total_cases                         1.000000   0.791578            0.821181
# new_cases                           0.791578   1.000000            0.994180
# new_cases_smoothed                  0.821181   0.994180            1.000000
# total_deaths                        0.994658   0.817455            0.846432
# new_deaths                          0.691311   0.947224            0.937602
# new_deaths_smoothed                 0.744799   0.975917            0.975405
# total_cases_per_million             1.000000   0.791578            0.821181
# new_cases_per_million               0.791578   1.000000            0.994180
# new_cases_smoothed_per_million      0.821181   0.994180            1.000000
# total_deaths_per_million            0.994658   0.817455            0.846432
# new_deaths_per_million              0.691384   0.947251            0.937638
# new_deaths_smoothed_per_million     0.744811   0.975912            0.975403
# total_tests                         0.997346   0.724530            0.762690
# new_tests                           0.920559   0.908670            0.924934
# total_tests_per_thousand            0.997346   0.724530            0.762690
# new_tests_per_thousand              0.920537   0.908711            0.924955
# new_tests_smoothed                  0.949058   0.917932            0.939840
# new_tests_smoothed_per_thousand     0.949054   0.917931            0.939841
# tests_per_case                     -0.179063  -0.534972           -0.510990
# positive_rate                       0.081905   0.532753            0.497143
# stringency_index                    0.123213   0.358130            0.335548
#
#                                  total_deaths  new_deaths  \
# total_cases                          0.994658    0.691311
# new_cases                            0.817455    0.947224
# new_cases_smoothed                   0.846432    0.937602
# total_deaths                         1.000000    0.713620
# new_deaths                           0.713620    1.000000
# new_deaths_smoothed                  0.775178    0.967946
# total_cases_per_million              0.994658    0.691311
# new_cases_per_million                0.817456    0.947223
# new_cases_smoothed_per_million       0.846432    0.937602
# total_deaths_per_million             1.000000    0.713620
# new_deaths_per_million               0.713699    1.000000
# new_deaths_smoothed_per_million      0.775189    0.967930
# total_tests                          0.988230    0.603845
# new_tests                            0.943904    0.805785
# total_tests_per_thousand             0.988230    0.603845
# new_tests_per_thousand               0.943896    0.805798
# new_tests_smoothed                   0.969813    0.816040
# new_tests_smoothed_per_thousand      0.969815    0.816047
# tests_per_case                      -0.256856   -0.630917
# positive_rate                        0.175429    0.643621
# stringency_index                    -0.422976    0.409018
#
#                                  new_deaths_smoothed  total_cases_per_million  \
# total_cases                                 0.744799                 1.000000
# new_cases                                   0.975917                 0.791578
# new_cases_smoothed                          0.975405                 0.821181
# total_deaths                                0.775178                 0.994658
# new_deaths                                  0.967946                 0.691311
# new_deaths_smoothed                         1.000000                 0.744799
# total_cases_per_million                     0.744799                 1.000000
# new_cases_per_million                       0.975917                 0.791578
# new_cases_smoothed_per_million              0.975405                 0.821181
# total_deaths_per_million                    0.775178                 0.994658
# new_deaths_per_million                      0.967961                 0.691384
# new_deaths_smoothed_per_million             1.000000                 0.744811
# total_tests                                 0.673645                 0.997346
# new_tests                                   0.867389                 0.920559
# total_tests_per_thousand                    0.673644                 0.997346
# new_tests_per_thousand                      0.867424                 0.920537
# new_tests_smoothed                          0.879474                 0.949058
# new_tests_smoothed_per_thousand             0.879489                 0.949054
# tests_per_case                             -0.634334                -0.179063
# positive_rate                               0.638365                 0.081905
# stringency_index                            0.395684                 0.123213
#
#                                  new_cases_per_million  \
# total_cases                                   0.791578
# new_cases                                     1.000000
# new_cases_smoothed                            0.994180
# total_deaths                                  0.817456
# new_deaths                                    0.947223
# new_deaths_smoothed                           0.975917
# total_cases_per_million                       0.791578
# new_cases_per_million                         1.000000
# new_cases_smoothed_per_million                0.994180
# total_deaths_per_million                      0.817456
# new_deaths_per_million                        0.947251
# new_deaths_smoothed_per_million               0.975912
# total_tests                                   0.724531
# new_tests                                     0.908670
# total_tests_per_thousand                      0.724531
# new_tests_per_thousand                        0.908712
# new_tests_smoothed                            0.917932
# new_tests_smoothed_per_thousand               0.917932
# tests_per_case                               -0.534971
# positive_rate                                 0.532752
# stringency_index                              0.358131
#
#                                  new_cases_smoothed_per_million  \
# total_cases                                            0.821181
# new_cases                                              0.994180
# new_cases_smoothed                                     1.000000
# total_deaths                                           0.846432
# new_deaths                                             0.937602
# new_deaths_smoothed                                    0.975405
# total_cases_per_million                                0.821181
# new_cases_per_million                                  0.994180
# new_cases_smoothed_per_million                         1.000000
# total_deaths_per_million                               0.846432
# new_deaths_per_million                                 0.937638
# new_deaths_smoothed_per_million                        0.975403
# total_tests                                            0.762690
# new_tests                                              0.924934
# total_tests_per_thousand                               0.762690
# new_tests_per_thousand                                 0.924955
# new_tests_smoothed                                     0.939840
# new_tests_smoothed_per_thousand                        0.939841
# tests_per_case                                        -0.510990
# positive_rate                                          0.497144
# stringency_index                                       0.335548
#
#                                  total_deaths_per_million  ...  \
# total_cases                                      0.994658  ...
# new_cases                                        0.817455  ...
# new_cases_smoothed                               0.846432  ...
# total_deaths                                     1.000000  ...
# new_deaths                                       0.713620  ...
# new_deaths_smoothed                              0.775178  ...
# total_cases_per_million                          0.994658  ...
# new_cases_per_million                            0.817456  ...
# new_cases_smoothed_per_million                   0.846432  ...
# total_deaths_per_million                         1.000000  ...
# new_deaths_per_million                           0.713699  ...
# new_deaths_smoothed_per_million                  0.775189  ...
# total_tests                                      0.988230  ...
# new_tests                                        0.943904  ...
# total_tests_per_thousand                         0.988230  ...
# new_tests_per_thousand                           0.943896  ...
# new_tests_smoothed                               0.969813  ...
# new_tests_smoothed_per_thousand                  0.969815  ...
# tests_per_case                                  -0.256856  ...
# positive_rate                                    0.175429  ...
# stringency_index                                -0.422975  ...
#
#                                  new_deaths_smoothed_per_million  total_tests  \
# total_cases                                             0.744811     0.997346
# new_cases                                               0.975912     0.724530
# new_cases_smoothed                                      0.975403     0.762690
# total_deaths                                            0.775189     0.988230
# new_deaths                                              0.967930     0.603845
# new_deaths_smoothed                                     1.000000     0.673645
# total_cases_per_million                                 0.744811     0.997346
# new_cases_per_million                                   0.975912     0.724531
# new_cases_smoothed_per_million                          0.975403     0.762690
# total_deaths_per_million                                0.775189     0.988230
# new_deaths_per_million                                  0.967945     0.603923
# new_deaths_smoothed_per_million                         1.000000     0.673664
# total_tests                                             0.673664     1.000000
# new_tests                                               0.867422     0.899268
# total_tests_per_thousand                                0.673664     1.000000
# new_tests_per_thousand                                  0.867458     0.899247
# new_tests_smoothed                                      0.879489     0.927702
# new_tests_smoothed_per_thousand                         0.879504     0.927697
# tests_per_case                                         -0.634356    -0.121458
# positive_rate                                           0.638330     0.013626
# stringency_index                                        0.395701    -0.513047
#
#                                  new_tests  total_tests_per_thousand  \
# total_cases                       0.920559                  0.997346
# new_cases                         0.908670                  0.724530
# new_cases_smoothed                0.924934                  0.762690
# total_deaths                      0.943904                  0.988230
# new_deaths                        0.805785                  0.603845
# new_deaths_smoothed               0.867389                  0.673644
# total_cases_per_million           0.920559                  0.997346
# new_cases_per_million             0.908670                  0.724531
# new_cases_smoothed_per_million    0.924934                  0.762690
# total_deaths_per_million          0.943904                  0.988230
# new_deaths_per_million            0.805851                  0.603923
# new_deaths_smoothed_per_million   0.867422                  0.673664
# total_tests                       0.899268                  1.000000
# new_tests                         1.000000                  0.899268
# total_tests_per_thousand          0.899268                  1.000000
# new_tests_per_thousand            1.000000                  0.899247
# new_tests_smoothed                0.978876                  0.927702
# new_tests_smoothed_per_thousand   0.978861                  0.927697
# tests_per_case                   -0.316232                 -0.121458
# positive_rate                     0.236821                  0.013625
# stringency_index                 -0.502479                 -0.513048
#
#                                  new_tests_per_thousand  new_tests_smoothed  \
# total_cases                                    0.920537            0.949058
# new_cases                                      0.908711            0.917932
# new_cases_smoothed                             0.924955            0.939840
# total_deaths                                   0.943896            0.969813
# new_deaths                                     0.805798            0.816040
# new_deaths_smoothed                            0.867424            0.879474
# total_cases_per_million                        0.920537            0.949058
# new_cases_per_million                          0.908712            0.917932
# new_cases_smoothed_per_million                 0.924955            0.939840
# total_deaths_per_million                       0.943896            0.969813
# new_deaths_per_million                         0.805864            0.816104
# new_deaths_smoothed_per_million                0.867458            0.879489
# total_tests                                    0.899247            0.927702
# new_tests                                      1.000000            0.978876
# total_tests_per_thousand                       0.899247            0.927702
# new_tests_per_thousand                         1.000000            0.978884
# new_tests_smoothed                             0.978884            1.000000
# new_tests_smoothed_per_thousand                0.978868            1.000000
# tests_per_case                                -0.316292           -0.345914
# positive_rate                                  0.236928            0.270416
# stringency_index                              -0.502466           -0.576602
#
#                                  new_tests_smoothed_per_thousand  \
# total_cases                                             0.949054
# new_cases                                               0.917931
# new_cases_smoothed                                      0.939841
# total_deaths                                            0.969815
# new_deaths                                              0.816047
# new_deaths_smoothed                                     0.879489
# total_cases_per_million                                 0.949054
# new_cases_per_million                                   0.917932
# new_cases_smoothed_per_million                          0.939841
# total_deaths_per_million                                0.969815
# new_deaths_per_million                                  0.816111
# new_deaths_smoothed_per_million                         0.879504
# total_tests                                             0.927697
# new_tests                                               0.978861
# total_tests_per_thousand                                0.927697
# new_tests_per_thousand                                  0.978868
# new_tests_smoothed                                      1.000000
# new_tests_smoothed_per_thousand                         1.000000
# tests_per_case                                         -0.345916
# positive_rate                                           0.270446
# stringency_index                                       -0.576623
#
#                                  tests_per_case  positive_rate  \
# total_cases                           -0.179063       0.081905
# new_cases                             -0.534972       0.532753
# new_cases_smoothed                    -0.510990       0.497143
# total_deaths                          -0.256856       0.175429
# new_deaths                            -0.630917       0.643621
# new_deaths_smoothed                   -0.634334       0.638365
# total_cases_per_million               -0.179063       0.081905
# new_cases_per_million                 -0.534971       0.532752
# new_cases_smoothed_per_million        -0.510990       0.497144
# total_deaths_per_million              -0.256856       0.175429
# new_deaths_per_million                -0.630895       0.643599
# new_deaths_smoothed_per_million       -0.634356       0.638330
# total_tests                           -0.121458       0.013626
# new_tests                             -0.316232       0.236821
# total_tests_per_thousand              -0.121458       0.013625
# new_tests_per_thousand                -0.316292       0.236928
# new_tests_smoothed                    -0.345914       0.270416
# new_tests_smoothed_per_thousand       -0.345916       0.270446
# tests_per_case                         1.000000      -0.884134
# positive_rate                         -0.884134       1.000000
# stringency_index                       0.403947      -0.422987
#
#                                  stringency_index
# total_cases                              0.123213
# new_cases                                0.358130
# new_cases_smoothed                       0.335548
# total_deaths                            -0.422976
# new_deaths                               0.409018
# new_deaths_smoothed                      0.395684
# total_cases_per_million                  0.123213
# new_cases_per_million                    0.358131
# new_cases_smoothed_per_million           0.335548
# total_deaths_per_million                -0.422975
# new_deaths_per_million                   0.409003
# new_deaths_smoothed_per_million          0.395701
# total_tests                             -0.513047
# new_tests                               -0.502479
# total_tests_per_thousand                -0.513048
# new_tests_per_thousand                  -0.502466
# new_tests_smoothed                      -0.576602
# new_tests_smoothed_per_thousand         -0.576623
# tests_per_case                           0.403947
# positive_rate                           -0.422987
# stringency_index                         1.000000
#
# [21 rows x 21 columns]

# %% [markdown]
# ## Relplot-

# %%
sns.relplot(x='new_cases_smoothed', y='new_deaths_smoothed', data=ind)
plt.ylabel('NEW DEATHS SMOOTHED',fontsize=10)
plt.xlabel('NEW CASES SMOOTHED',fontsize=10)
# Out:
# Text(0.5, 6.79999999999999, 'NEW CASES SMOOTHED')

# %%
sns.relplot(x='total_deaths',y='new_deaths',data=ind)
plt.xlabel('TOTAL DEATHS',fontsize=10)
plt.ylabel('NEW DEATHS',fontsize=10)
# Out:
# Text(-2.700000000000003, 0.5, 'NEW DEATHS')

# %%
sns.relplot(x='positive_rate',y='new_tests_smoothed_per_thousand',data=ind)
plt.xlabel('POSITIVE RATE',fontsize=10)
plt.ylabel('NEW TESTS SMOOTHED PER THOUSAND',fontsize=10)
# Out:
# Text(6.799999999999997, 0.5, 'NEW TESTS SMOOTHED PER THOUSAND')

# %%
sns.relplot(x='positive_rate',y='new_deaths',data=ind)
plt.xlabel('POSITIVE RATE',fontsize=10)
plt.ylabel('NEW DEATHS',fontsize=10)
# Out:
# Text(-2.700000000000003, 0.5, 'NEW DEATHS')

# %%
sns.relplot(x='total_cases',y='total_deaths',data=ind)
plt.ylabel('TOTAL DEATHS',fontsize=10)
plt.xlabel('TOTAL CASES',fontsize=10)
# Out:
# Text(0.5, 6.79999999999999, 'TOTAL CASES')

# %% [markdown]
# # Single Value plots

# %% [markdown]
# ## For Positive rate-

# %%
ind=ind.set_index('date')

# %%
ind['positive_rate'].plot(figsize=(14,6))
plt.ylabel('POSITIVE RATE',fontsize=10)
plt.xlabel('DATE',fontsize=12)
# Out:
# Text(0.5, 0, 'DATE')

# %%
ind['new_deaths_smoothed'].plot(figsize=(14,6))
plt.ylabel('NEW DEATHS SMOOTHED',fontsize=10)
plt.xlabel('DATE',fontsize=12)
# Out:
# Text(0.5, 0, 'DATE')

# %%
ind['new_tests_smoothed_per_thousand'].plot(figsize=(14,6))
plt.ylabel('NEW TESTS SMOOTHED PER THOUSAND',fontsize=10)
plt.xlabel('DATE',fontsize=12)
# Out:
# Text(0.5, 0, 'DATE')

# %%
ind['total_tests'].plot(figsize=(14,6))
plt.ylabel('TOTAL TESTS',fontsize=10)
plt.xlabel('DATE',fontsize=12)
# Out:
# Text(0.5, 0, 'DATE')

# %%
ind['stringency_index'].plot(figsize=(14,6))
plt.ylabel('STRINGENCY INDEX',fontsize=10)
plt.xlabel('DATE',fontsize=12)
# Out:
# Text(0.5, 0, 'DATE')

# %%
sns.relplot(x='total_tests',y='positive_rate',data=ind)
plt.ylabel('POSITIVEE RATE',fontsize=10)
plt.xlabel('TOTAL TESTS',fontsize=10)
# Out:
# Text(0.5, 6.79999999999999, 'TOTAL TESTS')

# %%
sns.relplot(x='total_tests',y='total_deaths_per_million',data=ind)
plt.ylabel('TOTAL DEATHS PER MILLION',fontsize=10)
plt.xlabel('TOTAL TESTS',fontsize=10)
# Out:
# Text(0.5, 6.79999999999999, 'TOTAL TESTS')

# %%
sns.relplot(x='total_tests',y='tests_per_case',data=ind)
plt.ylabel('TESTS PER CASE',fontsize=10)
plt.xlabel('TOTAL TESTS',fontsize=10)
# Out:
# Text(0.5, 6.79999999999999, 'TOTAL TESTS')

# %%
new_data=['iso_code', 'continent', 'location', 'date', 'total_cases','total_deaths','new_deaths_smoothed','population', 
              'population_density', 'median_age', 'aged_65_older','aged_70_older', 'gdp_per_capita', 'extreme_poverty',
              'cardiovasc_death_rate','diabetes_prevalence', 'female_smokers','male_smokers', 'handwashing_facilities',
              'hospital_beds_per_thousand','life_expectancy', 'human_development_index']

# %%
new_df=df[new_data]

# %%
new_df['date'] = pd.to_datetime(new_df['date'])
# Out:
# <ipython-input-27-adc1d48a344e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['date'] = pd.to_datetime(new_df['date'])

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55247 entries, 0 to 55246
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   iso_code                    54934 non-null  object
#  1   continent                   54621 non-null  object
#  2   location                    55247 non-null  object
#  3   date                        55247 non-null  datetime64[ns]
#  4   total_cases                 51615 non-null  float64
#  5   total_deaths                42439 non-null  float64
#  6   new_deaths_smoothed         53524 non-null  float64
#  7   population                  54934 non-null  float64
#  8   population_density          52354 non-null  float64
#  9   median_age                  49157 non-null  float64
#  10  aged_65_older               48418 non-null  float64
#  11  aged_70_older               48901 non-null  float64
#  12  gdp_per_capita              48510 non-null  float64
#  13  extreme_poverty             32337 non-null  float64
#  14  cardiovasc_death_rate       49133 non-null  float64
#  15  diabetes_prevalence         50924 non-null  float64
#  16  female_smokers              38259 non-null  float64
#  17  male_smokers                37766 non-null  float64
#  18  handwashing_facilities      23229 non-null  float64
#  19  hospital_beds_per_thousand  44273 non-null  float64
#  20  life_expectancy             54229 non-null  float64
#  21  human_development_index     47430 non-null  float64
# dtypes: datetime64[ns](1), float64(18), object(3)
# memory usage: 9.3+ MB

# %%
new_df.continent.unique()
# Out:
# array(['Asia', 'Europe', 'Africa', 'North America', 'South America',
#        'Oceania', nan], dtype=object)

# %%
Asia = new_df[new_df['continent']=='Asia']
Asia.location.unique()
# Out:
# array(['Afghanistan', 'Armenia', 'Azerbaijan', 'Bahrain', 'Bangladesh',
#        'Bhutan', 'Brunei', 'Cambodia', 'China', 'Georgia', 'Hong Kong',
#        'India', 'Indonesia', 'Iran', 'Iraq', 'Israel', 'Japan', 'Jordan',
#        'Kazakhstan', 'Kuwait', 'Kyrgyzstan', 'Laos', 'Lebanon',
#        'Malaysia', 'Maldives', 'Mongolia', 'Myanmar', 'Nepal', 'Oman',
#        'Pakistan', 'Palestine', 'Philippines', 'Qatar', 'Saudi Arabia',
#        'Singapore', 'South Korea', 'Sri Lanka', 'Syria', 'Taiwan',
#        'Tajikistan', 'Thailand', 'Timor', 'Turkey',
#        'United Arab Emirates', 'Uzbekistan', 'Vietnam', 'Yemen'],
#       dtype=object)

# %%
Asia.head()
# Out:
#   iso_code continent     location       date  total_cases  total_deaths  \
# 0      AFG      Asia  Afghanistan 2019-12-31          NaN           NaN
# 1      AFG      Asia  Afghanistan 2020-01-01          NaN           NaN
# 2      AFG      Asia  Afghanistan 2020-01-02          NaN           NaN
# 3      AFG      Asia  Afghanistan 2020-01-03          NaN           NaN
# 4      AFG      Asia  Afghanistan 2020-01-04          NaN           NaN
#
#    new_deaths_smoothed  population  population_density  median_age  ...  \
# 0                  NaN  38928341.0              54.422        18.6  ...
# 1                  NaN  38928341.0              54.422        18.6  ...
# 2                  NaN  38928341.0              54.422        18.6  ...
# 3                  NaN  38928341.0              54.422        18.6  ...
# 4                  NaN  38928341.0              54.422        18.6  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0        1803.987              NaN                597.029
# 1        1803.987              NaN                597.029
# 2        1803.987              NaN                597.029
# 3        1803.987              NaN                597.029
# 4        1803.987              NaN                597.029
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# 0                 9.59             NaN           NaN                  37.746
# 1                 9.59             NaN           NaN                  37.746
# 2                 9.59             NaN           NaN                  37.746
# 3                 9.59             NaN           NaN                  37.746
# 4                 9.59             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index
# 0                         0.5            64.83                    0.498
# 1                         0.5            64.83                    0.498
# 2                         0.5            64.83                    0.498
# 3                         0.5            64.83                    0.498
# 4                         0.5            64.83                    0.498
#
# [5 rows x 22 columns]

# %%
dates=[]
dates = list(Asia.date)

# %%
total_deaths1 = []
Armenia = Asia[Asia['location']=='Armenia']
Armenia = Armenia.dropna()
pop = Armenia.population.unique()
for total_deaths in Armenia.total_cases:
  total = total_deaths/pop[0]
  total_deaths1.append(total)
total_deaths2 = []
Nepal = Asia[Asia['location']=='Nepal']
Nepal = Nepal.dropna()
pop = Nepal.population.unique()
for total_deaths in Nepal.total_cases:
  total = total_deaths/pop[0]
  total_deaths2.append(total)
total_deaths3 = []
India = Asia[Asia['location']=='India']
India = India.dropna()
pop = India.population.unique()
for total_deaths in India.total_cases:
  total = total_deaths/pop[0]
  total_deaths3.append(total)
total_deaths4 = []
Pakistan = Asia[Asia['location']=='Pakistan']
Pakistan = Pakistan.dropna()
pop = Pakistan.population.unique()
for total_deaths in Pakistan.total_cases:
  total = total_deaths/pop[0]
  total_deaths4.append(total)
total_deaths5 = []
Thailand = Asia[Asia['location']=='Thailand']
Thaland = Thailand.dropna()
pop = Thailand.population.unique()
for total_deaths in Armenia.total_cases:
  total = total_deaths/pop[0]
  total_deaths5.append(total)
total_deaths6 = []
Vietnam = Asia[Asia['location']=='Vietnam']
Vietnam = Vietnam.dropna()
pop = Vietnam.population.unique()
for total_deaths in Armenia.total_cases:
  total = total_deaths/pop[0]
  total_deaths6.append(total)

# %%
dataframe = list(zip(dates,total_deaths1,total_deaths2,total_deaths3,total_deaths4,total_deaths5,total_deaths6))

# %%
df_Asia = pd.DataFrame(dataframe, columns = ['Date','Armenia', 'Nepal','India','Pakistan','Thailand','Vietnam'])

# %%
df_Asia.head()
# Out:
#         Date   Armenia     Nepal         India  Pakistan  Thailand   Vietnam
# 0 2019-12-31  0.000111  0.000010  5.434765e-08  0.000002  0.000005  0.000003
# 1 2020-01-01  0.000126  0.000010  6.014474e-08  0.000002  0.000005  0.000004
# 2 2020-01-02  0.000143  0.000013  6.521718e-08  0.000003  0.000006  0.000004
# 3 2020-01-03  0.000163  0.000014  6.739109e-08  0.000004  0.000007  0.000005
# 4 2020-01-04  0.000180  0.000015  9.057942e-08  0.000004  0.000008  0.000005

# %%
df_Asia = df_Asia.set_index('Date')

# %%
dims = (18,12)
fig, ax = plt.subplots(figsize=dims)
ax = sns.lineplot(ax=ax, data=df_Asia)
plt.setp(ax.get_legend().get_texts(), fontsize='20')
plt.setp(ax.get_legend().get_title(), fontsize='16')
plt.xlabel('DATE',fontsize=15)
plt.ylabel('TOTAL DEATH PER POPULATION',fontsize=15)
# Out:
# Text(0, 0.5, 'TOTAL DEATH PER POPULATION')

# %%
dims = (18,12)
fig, ax = plt.subplots(figsize=dims)
ax = sns.barplot(ax=ax, data=df_Asia)

# %%
dates_new=[]
dates_new = list(Asia.date)
new_deaths1 = []
Armenia_new = Asia[Asia['location']=='Armenia']
Armenia = Armenia_new.dropna()
for new_deaths in Armenia.new_deaths_smoothed:
  new_deaths1.append(new_deaths)
new_deaths2 = []
Nepal_new = Asia[Asia['location']=='Nepal']
Nepal = Nepal_new.dropna()
for new_deaths in Nepal.new_deaths_smoothed:
  new_deaths2.append(new_deaths)
new_deaths3 = []
India = Asia[Asia['location']=='India']
India = India.dropna()
for new_deaths in India.new_deaths_smoothed:
  new_deaths3.append(new_deaths)
new_deaths4 = []
Pakistan = Asia[Asia['location']=='Pakistan']
Pakistan = Pakistan.dropna()
for new_deaths in Pakistan.new_deaths_smoothed:
  new_deaths4.append(new_deaths)
new_deaths5 = []
Thailand = Asia[Asia['location']=='Thailand']
Thaland = Thailand.dropna()
for new_deaths in Armenia.new_deaths_smoothed:
  new_deaths5.append(new_deaths)
new_deaths6 = []
Vietnam = Asia[Asia['location']=='Vietnam']
Vietnam = Vietnam.dropna()
for new_deaths in Vietnam.new_deaths_smoothed:
  new_deaths6.append(new_deaths)

# %%
dataframe_new = list(zip(dates_new,new_deaths1,new_deaths2,new_deaths3,new_deaths4,new_deaths5,new_deaths6))

# %%
df_Asia_new = pd.DataFrame(dataframe_new, columns = ['Date','Armenia', 'Nepal','India','Pakistan','Thailand','Vietnam'])
df_Asia_new.head()
# Out:
#         Date  Armenia  Nepal  India  Pakistan  Thailand  Vietnam
# 0 2019-12-31    0.143  0.143  0.143     0.286     0.143    0.429
# 1 2020-01-01    0.143  0.286  0.286     0.429     0.143    0.714
# 2 2020-01-02    0.143  0.286  0.286     0.429     0.143    0.857
# 3 2020-01-03    0.429  0.286  0.286     0.714     0.429    1.143
# 4 2020-01-04    0.429  0.286  0.429     0.857     0.429    1.143

# %%
df_Asia_new = df_Asia_new.set_index('Date')

# %%
dims = (18,12)
fig, ax = plt.subplots(figsize=dims)
ax = sns.barplot(ax=ax, data=df_Asia_new)

# %%
Asia_sam = Asia[Asia['location'].isin(['Armenia','Nepal','India','Pakistan','Thailand','Vietnam'])]

# %%
Asia_sam.location.unique()
# Out:
# array(['Armenia', 'India', 'Nepal', 'Pakistan', 'Thailand', 'Vietnam'],
#       dtype=object)

# %%
Asia_sam.aged_65_older.unique()
# Out:
# array([11.232,  5.989,  5.809,  4.495, 11.373,  7.15 ])

# %%
Asia_sam.male_smokers.unique()
# Out:
# array([52.1, 20.6, 37.8, 36.7, 38.8, 45.9])

# %%
Asia_sam.hospital_beds_per_thousand.unique()
# Out:
# array([4.2 , 0.53, 0.3 , 0.6 , 2.1 , 2.6 ])

# %%
Asia_sam.gdp_per_capita.unique()
# Out:
# array([ 8787.58 ,  6426.674,  2442.804,  5034.708, 16277.671,  6171.884])

# %% [markdown]
# # Thank you-
