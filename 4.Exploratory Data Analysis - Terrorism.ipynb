# %% [markdown]
# # Exploratory Data Analysis-Terrorism

# %%
# Importing all libraries required in this notebook
import pandas as pd
import numpy as np  
import seaborn as sns
import matplotlib.pyplot as plt  
# %matplotlib inline

# %%
df = pd.read_csv('globalterrorism.csv', encoding='ISO-8859-1',
                          usecols=[0, 1, 2, 3, 8, 11, 12, 13, 14, 29, 35, 84, 100, 103])

# %%
df
# Out:
#              eventid  iyear  imonth  iday         country_txt  \
# 0       1.970000e+11   1970       7     2  Dominican Republic
# 1       1.970000e+11   1970       0     0              Mexico
# 2       1.970010e+11   1970       1     0         Philippines
# 3       1.970010e+11   1970       1     0              Greece
# 4       1.970010e+11   1970       1     0               Japan
# ...              ...    ...     ...   ...                 ...
# 181686  2.017120e+11   2017      12    31             Somalia
# 181687  2.017120e+11   2017      12    31               Syria
# 181688  2.017120e+11   2017      12    31         Philippines
# 181689  2.017120e+11   2017      12    31               India
# 181690  2.017120e+11   2017      12    31         Philippines
#
#               provstate           city   latitude   longitude  \
# 0                   NaN  Santo Domingo  18.456792  -69.951164
# 1               Federal    Mexico city  19.371887  -99.086624
# 2                Tarlac        Unknown  15.478598  120.599741
# 3                Attica         Athens  37.997490   23.762728
# 4               Fukouka        Fukouka  33.580412  130.396361
# ...                 ...            ...        ...         ...
# 181686  Middle Shebelle  Ceelka Geelow   2.359673   45.385034
# 181687         Lattakia         Jableh  35.407278   35.942679
# 181688      Maguindanao       Kubentog   6.900742  124.437908
# 181689          Manipur         Imphal  24.798346   93.940430
# 181690      Maguindanao  Cotabato City   7.209594  124.241966
#
#                        attacktype1_txt                targtype1_txt  \
# 0                        Assassination  Private Citizens & Property
# 1          Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2                        Assassination          Journalists & Media
# 3                    Bombing/Explosion      Government (Diplomatic)
# 4       Facility/Infrastructure Attack      Government (Diplomatic)
# ...                                ...                          ...
# 181686                   Armed Assault                     Military
# 181687               Bombing/Explosion                     Military
# 181688  Facility/Infrastructure Attack  Private Citizens & Property
# 181689               Bombing/Explosion         Government (General)
# 181690               Bombing/Explosion                      Unknown
#
#                                  weapsubtype1_txt  nkillter  nwoundte
# 0                                             NaN       NaN       NaN
# 1                                             NaN       NaN       NaN
# 2                                             NaN       NaN       NaN
# 3                          Unknown Explosive Type       NaN       NaN
# 4                                             NaN       NaN       NaN
# ...                                           ...       ...       ...
# 181686                           Unknown Gun Type       0.0       0.0
# 181687  Projectile (rockets, mortars, RPGs, etc.)       0.0       0.0
# 181688                                 Arson/Fire       0.0       0.0
# 181689                                    Grenade       0.0       0.0
# 181690                     Unknown Explosive Type       0.0       0.0
#
# [181691 rows x 14 columns]

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'country_txt', 'provstate',
#        'city', 'latitude', 'longitude', 'attacktype1_txt', 'targtype1_txt',
#        'weapsubtype1_txt', 'nkillter', 'nwoundte'],
#       dtype='object')

# %%
df = df.rename(columns={'eventid':'ID', 'iyear':'Year', 'imonth':'Month', 'iday':'Day',
             'country_txt':'Country', 'provstate':'State','city':'City', 'targtype1_txt':'Target',
             'weapsubtype1_txt': 'Weapon', 'attacktype1_txt': 'Attacktype', 'nkillter':'Fatalities', 
             'nwoundte':'Injuries'})

# %%
df
# Out:
#                   ID  Year  Month  Day             Country            State  \
# 0       1.970000e+11  1970      7    2  Dominican Republic              NaN
# 1       1.970000e+11  1970      0    0              Mexico          Federal
# 2       1.970010e+11  1970      1    0         Philippines           Tarlac
# 3       1.970010e+11  1970      1    0              Greece           Attica
# 4       1.970010e+11  1970      1    0               Japan          Fukouka
# ...              ...   ...    ...  ...                 ...              ...
# 181686  2.017120e+11  2017     12   31             Somalia  Middle Shebelle
# 181687  2.017120e+11  2017     12   31               Syria         Lattakia
# 181688  2.017120e+11  2017     12   31         Philippines      Maguindanao
# 181689  2.017120e+11  2017     12   31               India          Manipur
# 181690  2.017120e+11  2017     12   31         Philippines      Maguindanao
#
#                  City   latitude   longitude                      Attacktype  \
# 0       Santo Domingo  18.456792  -69.951164                   Assassination
# 1         Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)
# 2             Unknown  15.478598  120.599741                   Assassination
# 3              Athens  37.997490   23.762728               Bombing/Explosion
# 4             Fukouka  33.580412  130.396361  Facility/Infrastructure Attack
# ...               ...        ...         ...                             ...
# 181686  Ceelka Geelow   2.359673   45.385034                   Armed Assault
# 181687         Jableh  35.407278   35.942679               Bombing/Explosion
# 181688       Kubentog   6.900742  124.437908  Facility/Infrastructure Attack
# 181689         Imphal  24.798346   93.940430               Bombing/Explosion
# 181690  Cotabato City   7.209594  124.241966               Bombing/Explosion
#
#                              Target  \
# 0       Private Citizens & Property
# 1           Government (Diplomatic)
# 2               Journalists & Media
# 3           Government (Diplomatic)
# 4           Government (Diplomatic)
# ...                             ...
# 181686                     Military
# 181687                     Military
# 181688  Private Citizens & Property
# 181689         Government (General)
# 181690                      Unknown
#
#                                            Weapon  Fatalities  Injuries
# 0                                             NaN         NaN       NaN
# 1                                             NaN         NaN       NaN
# 2                                             NaN         NaN       NaN
# 3                          Unknown Explosive Type         NaN       NaN
# 4                                             NaN         NaN       NaN
# ...                                           ...         ...       ...
# 181686                           Unknown Gun Type         0.0       0.0
# 181687  Projectile (rockets, mortars, RPGs, etc.)         0.0       0.0
# 181688                                 Arson/Fire         0.0       0.0
# 181689                                    Grenade         0.0       0.0
# 181690                     Unknown Explosive Type         0.0       0.0
#
# [181691 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 14 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   ID          181691 non-null  float64
#  1   Year        181691 non-null  int64
#  2   Month       181691 non-null  int64
#  3   Day         181691 non-null  int64
#  4   Country     181691 non-null  object
#  5   State       181270 non-null  object
#  6   City        181257 non-null  object
#  7   latitude    177135 non-null  float64
#  8   longitude   177134 non-null  float64
#  9   Attacktype  181691 non-null  object
#  10  Target      181691 non-null  object
#  11  Weapon      160923 non-null  object
#  12  Fatalities  114733 non-null  float64
#  13  Injuries    112548 non-null  float64
# dtypes: float64(5), int64(3), object(6)
# memory usage: 19.4+ MB

# %%
df.corr()
# Out:
#                   ID      Year     Month       Day  latitude  longitude  \
# ID          1.000000  0.999996  0.002705  0.018270  0.166886   0.003907
# Year        0.999996  1.000000  0.000139  0.018254  0.166933   0.003917
# Month       0.002705  0.000139  1.000000  0.005497 -0.015978  -0.003880
# Day         0.018270  0.018254  0.005497  1.000000  0.003423  -0.002285
# latitude    0.166886  0.166933 -0.015978  0.003423  1.000000   0.001463
# longitude   0.003907  0.003917 -0.003880 -0.002285  0.001463   1.000000
# Fatalities  0.027580  0.027563  0.003462 -0.002012 -0.003282  -0.004713
# Injuries    0.027904  0.027879  0.005091  0.001812  0.021855   0.020186
#
#             Fatalities  Injuries
# ID            0.027580  0.027904
# Year          0.027563  0.027879
# Month         0.003462  0.005091
# Day          -0.002012  0.001812
# latitude     -0.003282  0.021855
# longitude    -0.004713  0.020186
# Fatalities    1.000000  0.594125
# Injuries      0.594125  1.000000

# %%
sns.heatmap(df.corr(), annot=True)

# %%
pd.DataFrame(df.isnull().sum(), columns= ['Number of missing values'])
# Out:
#             Number of missing values
# ID                                 0
# Year                               0
# Month                              0
# Day                                0
# Country                            0
# State                            421
# City                             434
# latitude                        4556
# longitude                       4557
# Attacktype                         0
# Target                             0
# Weapon                         20768
# Fatalities                     66958
# Injuries                       69143

# %%
df = df[df['longitude'].notna()]

# %%
pd.DataFrame(df.isnull().sum(), columns= ['Number of missing values'])
# Out:
#             Number of missing values
# ID                                 0
# Year                               0
# Month                              0
# Day                                0
# Country                            0
# State                            409
# City                             426
# latitude                           0
# longitude                          0
# Attacktype                         0
# Target                             0
# Weapon                         19722
# Fatalities                     63417
# Injuries                       65571

# %%
clean_lats = df['latitude']
clean_lons = df['longitude']
lats = clean_lats.tolist()
lons = clean_lons.tolist()

# %%
a=df[['ID','Year']]
a.groupby('Year').first()
# Out:
#                 ID
# Year
# 1970  1.970000e+11
# 1971  1.971010e+11
# 1972  1.972000e+11
# 1973  1.973010e+11
# 1974  1.974000e+11
# 1975  1.975000e+11
# 1976  1.976000e+11
# 1977  1.977000e+11
# 1978  1.978000e+11
# 1979  1.979000e+11
# 1980  1.980010e+11
# 1981  1.981010e+11
# 1982  1.982000e+11
# 1983  1.983010e+11
# 1984  1.984010e+11
# 1985  1.985010e+11
# 1986  1.981030e+11
# 1987  1.986010e+11
# 1988  1.988010e+11
# 1989  1.989010e+11
# 1990  1.990010e+11
# 1991  1.990010e+11
# 1992  1.992010e+11
# 1994  1.994010e+11
# 1995  1.995010e+11
# 1996  1.996010e+11
# 1997  1.997010e+11
# 1998  1.998010e+11
# 1999  1.999010e+11
# 2000  2.000010e+11
# 2001  2.001010e+11
# 2002  2.002010e+11
# 2003  2.003010e+11
# 2004  2.004000e+11
# 2005  2.005010e+11
# 2006  2.006010e+11
# 2007  2.007010e+11
# 2008  2.008010e+11
# 2009  2.009010e+11
# 2010  2.010010e+11
# 2011  2.011010e+11
# 2012  2.012010e+11
# 2013  2.013010e+11
# 2014  2.014010e+11
# 2015  2.014120e+11
# 2016  2.016010e+11
# 2017  2.016120e+11

# %%
b=df[['Country','State','City']]
y=b['Country'].value_counts().reset_index()
y[:20]
# Out:
#              index  Country
# 0             Iraq    24487
# 1         Pakistan    14318
# 2      Afghanistan    12639
# 3            India    11801
# 4         Colombia     7835
# 5      Philippines     6528
# 6             Peru     5808
# 7   United Kingdom     5227
# 8      El Salvador     4846
# 9           Turkey     4126
# 10         Somalia     4120
# 11         Nigeria     3866
# 12        Thailand     3806
# 13           Yemen     3270
# 14           Spain     3195
# 15       Sri Lanka     2909
# 16   United States     2835
# 17          France     2672
# 18         Algeria     2617
# 19           Egypt     2458

# %%
plt.figure(figsize=(12,7))
x=y['index'][:20]
y=y['Country'][:20]
plt.title("TOP 20 COUNTERY RECORD IN ONE SHEET")
plt.xlabel('COUNTRYS',fontsize=15)
plt.xticks(rotation=90)
plt.ylabel('TOTAL RECORD COUNTERY WISE',fontsize=15)
plt.bar(x,y,color='darkgray')
plt.show()

# %%
z=b['State'].value_counts().reset_index()
z[:20]
# Out:
#                                   index  State
# 0                               Baghdad   7645
# 1                      Northern Ireland   4497
# 2                           Balochistan   3710
# 3                               Saladin   3411
# 4                              Al Anbar   3299
# 5                               Nineveh   3241
# 6                                 Sindh   3205
# 7                    Khyber Pakhtunkhwa   3084
# 8                                Diyala   3041
# 9                                  Lima   2615
# 10                    Jammu and Kashmir   2454
# 11  Federally Administered Tribal Areas   2392
# 12                         San Salvador   1900
# 13                            Antioquia   1891
# 14                               Punjab   1778
# 15                               Kirkuk   1669
# 16                Santiago Metropolitan   1639
# 17                             Banaadir   1612
# 18                            West Bank   1582
# 19                       Basque Country   1446

# %%
plt.figure(figsize=(12,7))
x=z['index'][:20]
y=z['State'][:20]
plt.title("TOP 10 STATE RECORD IN ONE SHEET")
plt.xlabel('STATE',fontsize=15)
plt.xticks(rotation=90)
plt.ylabel('TOTAL RECORD STATE WISE',fontsize=15)
plt.bar(x,y,color='darkgray')
plt.show()

# %%
c=df[['Year','Fatalities','Injuries']]
d=c.groupby(['Year']).sum().reset_index()
d
# Out:
#     Year  Fatalities  Injuries
# 0   1970        15.0       1.0
# 1   1971         4.0       0.0
# 2   1972        18.0       2.0
# 3   1973        21.0       1.0
# 4   1974        22.0       7.0
# 5   1975       106.0       4.0
# 6   1976        16.0       3.0
# 7   1977        20.0       3.0
# 8   1978        34.0       6.0
# 9   1979        95.0       9.0
# 10  1980        73.0      14.0
# 11  1981        48.0      23.0
# 12  1982        85.0      10.0
# 13  1983        99.0       7.0
# 14  1984       163.0      14.0
# 15  1985       195.0      10.0
# 16  1986       171.0       8.0
# 17  1987        46.0       2.0
# 18  1988        28.0       3.0
# 19  1989        16.0       4.0
# 20  1990        14.0       3.0
# 21  1991        29.0       3.0
# 22  1992        11.0       8.0
# 23  1994        74.0      11.0
# 24  1995       152.0       6.0
# 25  1996        53.0       2.0
# 26  1997       204.0      53.0
# 27  1998       619.0      16.0
# 28  1999       276.0      34.0
# 29  2000       398.0      40.0
# 30  2001       423.0      51.0
# 31  2002       348.0      23.0
# 32  2003       301.0      32.0
# 33  2004       779.0     256.0
# 34  2005       403.0      29.0
# 35  2006       439.0     108.0
# 36  2007      1023.0     120.0
# 37  2008       739.0      79.0
# 38  2009       665.0      55.0
# 39  2010       641.0     125.0
# 40  2011       836.0     209.0
# 41  2012      3046.0     442.0
# 42  2013      3533.0     556.0
# 43  2014     10294.0    1848.0
# 44  2015     11599.0    2944.0
# 45  2016     11672.0    2676.0
# 46  2017      8074.0    2150.0

# %%
plt.figure(figsize=(12,7))
x=d['Year']
y=d['Fatalities']
plt.title("TOTAL RECORD IN ONE SHEET")
plt.xlabel('YEAR',fontsize=15)
plt.ylabel('TOTAL FATALITIES YEAR WISE',fontsize=15)
plt.bar(x,y,color='darkgray')
plt.show()

# %%
plt.figure(figsize=(12,7))
x=d['Year']
y=d['Injuries']
plt.title("TOTAL RECORD IN ONE SHEET")
plt.xlabel('YEAR',fontsize=15)
plt.ylabel('TOTAL INJURIES YEAR WISE',fontsize=15)
plt.bar(x,y,color='darkgray')
plt.show()

# %%
e=df[['Year','Attacktype','Target']]
x=e['Year'].value_counts().reset_index()
x
# Out:
#     index   Year
# 0    2014  16794
# 1    2015  14861
# 2    2016  13530
# 3    2013  11926
# 4    2017  10853
# 5    2012   8470
# 6    2011   5048
# 7    1992   4832
# 8    2010   4818
# 9    2008   4756
# 10   2009   4706
# 11   1991   4405
# 12   1989   4147
# 13   1990   3648
# 14   1988   3471
# 15   1994   3295
# 16   1984   3198
# 17   2007   3190
# 18   1997   2996
# 19   1987   2989
# 20   1995   2920
# 21   1996   2909
# 22   2006   2716
# 23   1985   2680
# 24   1986   2680
# 25   1983   2670
# 26   1980   2561
# 27   1979   2533
# 28   1981   2469
# 29   1982   2408
# 30   2005   1985
# 31   2001   1883
# 32   2000   1772
# 33   1978   1455
# 34   1999   1341
# 35   2002   1310
# 36   1977   1292
# 37   2003   1263
# 38   2004   1137
# 39   1976    900
# 40   1998    891
# 41   1975    727
# 42   1970    643
# 43   1974    577
# 44   1972    551
# 45   1973    465
# 46   1971    463

# %%
plt.figure(figsize=(10,7))
y = x['Year']
x = x['index']
plt.bar(x,y, width=0.85, alpha=0.7, color='darkgrey',  ecolor='black')
plt.xlabel('YEAR',fontsize=15)
plt.ylabel('TOTAL ATTACK ENTERYS',fontsize=15)
# Out:
# Text(0, 0.5, 'TOTAL ATTACK ENTERYS')

# %%
f=df[['Attacktype','Target']]

# %%
g=f['Target'].value_counts().reset_index()
g
# Out:
#                              index  Target
# 0      Private Citizens & Property   42568
# 1                         Military   26893
# 2                           Police   24140
# 3             Government (General)   20809
# 4                         Business   20274
# 5                   Transportation    6550
# 6                          Unknown    5831
# 7                        Utilities    5552
# 8   Religious Figures/Institutions    4382
# 9          Educational Institution    4269
# 10         Government (Diplomatic)    3515
# 11    Terrorists/Non-State Militia    2972
# 12             Journalists & Media    2855
# 13         Violent Political Party    1839
# 14             Airports & Aircraft    1310
# 15               Telecommunication     996
# 16                             NGO     942
# 17                        Tourists     422
# 18                        Maritime     314
# 19            Food or Water Supply     301
# 20                Abortion Related     263
# 21                           Other     137

# %%
plt.figure(figsize=(12,7))
plt.pie(g['Target'][:10],labels=g['index'][:10],autopct='%0.2f%%',shadow=True,counterclock=True)
plt.title('PRECENTAGE RECORD OF TOP 10 TARGET THROUG PIE CHART',fontsize=20)
plt.show()

# %%
h=f['Attacktype'].value_counts().reset_index()
h
# Out:
#                                  index  Attacktype
# 0                    Bombing/Explosion       86843
# 1                        Armed Assault       41107
# 2                        Assassination       18819
# 3          Hostage Taking (Kidnapping)       10671
# 4       Facility/Infrastructure Attack       10186
# 5                              Unknown        6931
# 6                      Unarmed Assault         986
# 7  Hostage Taking (Barricade Incident)         962
# 8                            Hijacking         629

# %%
plt.figure(figsize=(12,7))
plt.pie(h['Attacktype'][:7],labels=h['index'][:7],autopct='%0.2f%%',shadow=True,counterclock=True)
plt.title('PRECENTAGE RECORD OF TOP 7 ATTACKTYPE THROUG PIE CHART',fontsize=20)
plt.show()

# %%
k=df['Weapon'].value_counts().reset_index()
k
# Out:
#                                         index  Weapon
# 0                      Unknown Explosive Type   44001
# 1                            Unknown Gun Type   32725
# 2           Automatic or Semi-Automatic Rifle   16026
# 3                                     Vehicle    9852
# 4   Projectile (rockets, mortars, RPGs, etc.)    9725
# 5                        Other Explosive Type    7282
# 6                                     Handgun    6565
# 7                                     Grenade    5112
# 8                                    Landmine    4122
# 9                                  Arson/Fire    4104
# 10    Suicide (carried bodily by human being)    3235
# 11                             Remote Trigger    2709
# 12                Knife or Other Sharp Object    2508
# 13                                Sticky Bomb    1592
# 14               Molotov Cocktail/Petrol Bomb    1232
# 15                               Dynamite/TNT    1206
# 16              Rifle/Shotgun (non-automatic)    1164
# 17                        Gasoline or Alcohol     838
# 18                                  Time Fuse     787
# 19                                  Pipe Bomb     625
# 20                               Blunt Object     581
# 21                                Letter Bomb     530
# 22                         Hands, Feet, Fists     230
# 23                           Pressure Trigger     216
# 24                        Unknown Weapon Type     106
# 25            Rope or Other Strangling Device     100
# 26                             Other Gun Type      84
# 27                                  Poisoning      80
# 28                                  Explosive      65
# 29                                Suffocation      10

# %%
plt.figure(figsize=(12,7))
plt.pie(k['Weapon'][:10],labels=k['index'][:10],autopct='%0.2f%%',shadow=True,counterclock=True)
plt.title('PRECENTAGE RECORD OF TOP 10 WEAPONS THROUG PIE CHART',fontsize=20)
plt.show()

# %% [markdown]
# # Thank You
